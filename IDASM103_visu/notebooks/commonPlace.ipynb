# %% [markdown]
# # Exploration du fichier common place
#
# Ce notebook permet d'explorer les données des fichiers common place (format US et EU) placés dans le dossier data/raw
#
# - CommonPlace_20251109.csv
# - CommonPlace_20251109-EU.csv

# %%
import pandas as pd

us_data_set = pd.read_csv('../data/raw/CommonPlace_20251109.csv')
us_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20586 entries, 0 to 20585
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   the_geom                  20586 non-null  object
#  1   SEGMENTID                 20584 non-null  object
#  2   COMPLEXID                 7606 non-null   object
#  3   SAFTYPE                   11037 non-null  object
#  4   PLACEID                   20586 non-null  object
#  5   BIN                       14248 non-null  object
#  6   SOURCE                    20586 non-null  object
#  7   OBJECTID                  20586 non-null  object
#  8   SOS INDICATOR             20002 non-null  float64
#  9   FACILITY DOMAINS          20586 non-null  int64
#  10  BOROUGH CODE              20375 non-null  float64
#  11  SOURCE ID                 5895 non-null   object
#  12  CREATED_BY                983 non-null    object
# ...

# %%
eu_data_set = pd.read_csv('../data/raw/CommonPlace_20251109-EU.csv', delimiter=';')
eu_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20586 entries, 0 to 20585
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   the_geom                  20586 non-null  object
#  1   SEGMENTID                 20584 non-null  object
#  2   COMPLEXID                 7606 non-null   object
#  3   SAFTYPE                   11037 non-null  object
#  4   PLACEID                   20586 non-null  object
#  5   BIN                       14248 non-null  object
#  6   SOURCE                    20586 non-null  object
#  7   OBJECTID                  20586 non-null  object
#  8   SOS INDICATOR             20002 non-null  float64
#  9   FACILITY DOMAINS          20586 non-null  int64
#  10  BOROUGH CODE              20375 non-null  float64
#  11  SOURCE ID                 5895 non-null   object
#  12  CREATED_BY                983 non-null    object
# ...

# %%
eu_data_set.head()
# Out:
#                                    the_geom SEGMENTID COMPLEXID SAFTYPE  \
# 0  POINT (-74.097961931446 40.634604200807)    13,847       NaN     NaN
# 1  POINT (-73.981379489555 40.589105561411)    19,292       NaN     NaN
# 2  POINT (-73.943478646583 40.724827480825)    35,645     4,762       X
# 3  POINT (-73.858490015009 40.708424926703)   151,696       NaN     NaN
# 4  POINT (-74.024085858699 40.672444940613)    17,988       NaN     NaN
#
#      PLACEID        BIN SOURCE OBJECTID  SOS INDICATOR  FACILITY DOMAINS  ...  \
# 0     11,947  5,002,227    DOE   10,555            2.0                 2  ...
# 1     12,280  3,385,667    DOE    5,120            2.0                 3  ...
# 2  1,036,755  3,338,038  OTHER   20,345            2.0                10  ...
# 3      3,068  4,095,037    EMS    7,507            1.0                 2  ...
# 4      6,914        NaN   NOAA    7,005            NaN                11  ...
#
#    SOURCE ID CREATED_BY             CREATED_DATE MODIFIED_BY  \
# ...

# %%
# Supprimer le texte 'POINT (' et ')'
eu_data_set['the_geom'] = eu_data_set['the_geom'].str.replace('POINT ', '', regex=False)
eu_data_set['the_geom'] = eu_data_set['the_geom'].str.strip('()')

# Séparer longitude et latitude
eu_data_set[['longitude', 'latitude']] = eu_data_set['the_geom'].str.split(' ', expand=True).astype(float)

eu_data_set.head()
# Out:
#                            the_geom SEGMENTID COMPLEXID SAFTYPE    PLACEID  \
# 0  -74.097961931446 40.634604200807    13,847       NaN     NaN     11,947
# 1  -73.981379489555 40.589105561411    19,292       NaN     NaN     12,280
# 2  -73.943478646583 40.724827480825    35,645     4,762       X  1,036,755
# 3  -73.858490015009 40.708424926703   151,696       NaN     NaN      3,068
# 4  -74.024085858699 40.672444940613    17,988       NaN     NaN      6,914
#
#          BIN SOURCE OBJECTID  SOS INDICATOR  FACILITY DOMAINS  ...  \
# 0  5,002,227    DOE   10,555            2.0                 2  ...
# 1  3,385,667    DOE    5,120            2.0                 3  ...
# 2  3,338,038  OTHER   20,345            2.0                10  ...
# 3  4,095,037    EMS    7,507            1.0                 2  ...
# 4        NaN   NOAA    7,005            NaN                11  ...
#
#               CREATED_DATE MODIFIED_BY            MODIFIED_DATE FACILITY TYPE  \
# ...

# %%
# ploting the entries on a map

import plotly.express as px

fig = px.scatter_map(eu_data_set, lat='latitude', lon='longitude', color='FACILITY TYPE',
                     hover_name='FEATURE NAME',
                     title='Common places')
fig.show()
